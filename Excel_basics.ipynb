# %%
#Explain diffence between relative,absolute and mixed cell referencing you have the following dataset: vechile - car,bicyle,auto-rickshaw/ price - 500000,10500,25000

"""
If you write a formula in cell C2 as =B2 * 0.1 (to calculate a 10% tax) and then drag it down to cell C3, the formula automatically changes to =B3 * 0.1.
In your dataset: It’s used when you want the calculation to follow the row as you move down the list of vehicles.

"""
# Out:
# '\nIf you write a formula in cell C2 as =B2 * 0.1 (to calculate a 10% tax) and then drag it down to cell C3, the formula automatically changes to =B3 * 0.1.\nIn your dataset: It’s used when you want the calculation to follow the row as you move down the list of vehicles.\n\n'

# %%
#Write formula to calculate the total sales of car and bicyle only only.

"""
* car price in B2
* Bicyle price in B3

=sum(B2:B3)
or
=B2+B3

Total sales = 510500

"""
# Out:
# '\n* car price in B2\n* Bicyle price in B3\n\n=sum(B2:B3)\nor\n=B2+B3\n\nTotal sales = 510500\n\n'

# %%
#Using data below,write a formula to calculate the average sales of items priced above 100 about less than 300.

"""
Price average

* price located in B column

=Average(B3:B4)
=Average(150:250)
200

Sales average

* sales located in C column

=Average(C3:C4)
=Average(1200:1500)
1350

"""
# Out:
# '\nPrice average\n\n* price located in B column\n\n=Average(B3:B4)\n=Average(150:250)\n200\n\nSales average\n\n* sales located in C column\n\n=Average(C3:C4)\n=Average(1200:1500)\n1350\n\n'

# %%
#Count how many customer names are recoded

"""

Total customer name count 50

"""
# Out:
# '\n\nTotal customer name count 50\n\n'

# %%
#Calculate the total sales for eash row using a formula

"""

Total sales for eash row calculated in E2*F2=total sales

over all sales value for 16543

"""
# Out:
# '\n\nTotal sales for eash row calculated in E2*F2=total sales\n\nover all sales value for 16543\n\n'

# %%
#Calculate the total sale of notebook in the north region only

"""
Total sale of notebook in the north region value 2900

"""
# Out:
# '\nTotal sale of notebook in the north region value 2900\n\n'
